# %%
#notebook for Sp20 Haas SQL next steps

# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
import matplotlib.pyplot as plt
import plotly.offline as py
import zipfile
from pathlib import Path

Path.cwd()
# Out:
# PosixPath('/home/jovyan')

# %%
#SAT data 
school_scores = pd.read_csv('school_scores.csv')
school_scores.head(10)
# Out:
#    Year State.Code            State.Name  Total.Math  Total.Test-takers  \
# 0  2005         AL               Alabama         559               3985
# 1  2005         AK                Alaska         519               3996
# 2  2005         AZ               Arizona         530              18184
# 3  2005         AR              Arkansas         552               1600
# 4  2005         CA            California         522             186552
# 5  2005         CO              Colorado         560              11990
# 6  2005         CT           Connecticut         517              34313
# 7  2005         DE              Delaware         502               6257
# 8  2005         DC  District Of Columbia         478               3622
# 9  2005         FL               Florida         498              93505
#
#    Total.Verbal  Academic Subjects.Arts/Music.Average GPA  \
# 0           567                                      3.92
# ...

# %%
#Select, From, Where
# Out:
# 'SELECT State.Code FROM school_scores WHERE Total.Verbal > 500'

# %%
#Group by, Having

# %%
#Order by, Limit

# %%
#Joins
#Importing new dataset 
state_demographics = pd.read_csv('state_demographics.csv')
state_demographics.head(10)
# Out:
#                   State  Age.Percent 65 and Older  Age.Percent Under 18 Years  \
# 0         United States                      14.5                        23.1
# 1               Alabama                      15.3                        22.8
# 2                Alaska                       9.4                        25.3
# 3               Arizona                      15.9                        24.1
# 4              Arkansas                      15.7                        23.8
# 5            California                      12.9                        23.6
# 6              Colorado                      12.7                        23.3
# 7           Connecticut                      15.5                        21.6
# 8              Delaware                      16.4                        21.8
# 9  District Of Columbia                      11.3                        17.5
#
#    Age.Percent Under 5 Years  Education.Bachelor's Degree or Higher  \
# ...

# %%
#Cases
